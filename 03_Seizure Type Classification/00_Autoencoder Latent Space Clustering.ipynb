# %% [markdown]
# # Epileptic Seizure Classification with an Autoencoder and Classification of the Latent Space
# This notebook contains the classification of time series EEG data for the detection of epileptic seizures based on the preprocessed CHB-MIT Scalp EEG Database using an autoencoder-model with following clustering of the latent space.<br>
# The codes is structured as followed:
# 1. [Imports](#1-imports)
# 2. [Load Preprocessed Dataset](#2-load-preprocessed-dataset)
# 3. [Split Dataset](#3-split-dataset)
# 4. [Normalize Dataset](#4-normalize-dataset)
# 5. [Autoencoder](#5-autoencoder) <br>
# 5.1 [Define Autoencoder-Model](#51-define-autoencoder-model) <br>
# 5.2 [Compile Autoencoder-Model](#52-compile-autoencoder-model) <br>
# 5.3 [Train Autoencoder](#53-fit-autoencoder-model) <br>
# 5.4 [Visualize Reconstruction Error](#54-visualize-reconstruction)
# 6. [Split Autoencoder at Latent Space](#6-seperate-encoder)
# 7. [Clustering of Latent Space](#7-clustering-of-latent-space) <br>
# 7.1 [Define Cluster](#71-define-cluster) <br>
# 7.2 [Clustering](#72-clustering) <br>
# 7.3 [Visualize Cluster](#73-visualize-clusters) <br>
# 8. [Conclusion](#8-conclusion)

# %% [markdown]
# ## 1. Imports
# Import requiered libraries. <br>
# External packages can be installed via the `pip install -r requirements.txt` command or the notebook-cell below.

# %%
! pip install -r ../requirements.txt

# %%
# Import built-in libraries
import warnings
warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*") # Suppress SHAP warnings

# Import datascience libraries
import numpy as np

# Import preprocessing-libraries, classification metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
from imblearn.metrics import geometric_mean_score

# Import visualization libraries
import plotly.graph_objects as go
from prettytable import PrettyTable

# Import neural network framework & layers
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Dense, Flatten, BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tslearn.clustering import TimeSeriesKMeans

# Import explainability library
import shap

# %% [markdown]
# ## 2. Load Preprocessed Dataset
# In order to load the preprocessed dataset, that was created with the notebook `00_Preprocessing.ipynb`, is loaded and the numpy Arrays for the features and labels are extracted. <br>
# To enshure a functional distribution of the classes in the dataset, the classes with the respective amounts are plotted.

# %%
dataset = np.load('../00_Data/Processed-Data/classification_dataset_max.npz') # Load compressed numpy array
X = dataset["features"] # Extract feature-array from compressed file
y = dataset["labels"] # Extract label-array from compressed file

# %%
channels = ['F8-T8', 'T7-FT9', 'F4-C4', 'C3-P3', 'P7-T7', 'P7-O1', 'T8-P8', 'FP1-F7', 'P8-O2', 'T7-P7', 'C4-P4', 'FT10-T8', 'P4-O2', 'F7-T7', 'CZ-PZ', 'FP2-F8', 'P3-O1', 'FP1-F3','FP2-F4', 'FZ-CZ', 'F3-C3', 'FT9-FT10', 'age', 'gender']

# %%
print("Shapes: \n X:", X.shape, "y:", y.shape)
print("Unique Values:", np.unique(y, return_counts=True))
# Out:
# Shapes:
#  X: (16999, 1000, 24) y: (16999, 1)
# Unique Values: (array([0, 1], dtype=int8), array([9375, 7624]))

# %% [markdown]
# ## 3. Split Dataset
# In order to validate and test the trained classifier, the dataset must be split into a `train`, `test`, and `validation` subset. <br>
# To preserve an equal distribution within each split, the `stratify`-option is enabled.

# %%
X_train, X_rest, y_train, y_rest = train_test_split(X, y, test_size=0.4, shuffle=True, stratify=np.ravel(y), random_state=34)
X_test, X_val, y_test, y_val = train_test_split(X_rest, y_rest, test_size=0.5, shuffle=True, stratify=np.ravel(y_rest), random_state=34)

# %% [markdown]
# ## 4. Normalize Dataset
# When working with neural networks, it is imperative to normalize the data bevore training and testing. This enshures a faster training, avoids numerical instablities and provides a better generalization of the neural network. However with EEG-data, there are additional requirements due to the different characteristics and value-ranges of the individual channels. Therefore, the normalization is done channel by channel based on the training-subset and applied on the test- and validation-split.

# %%
def normalize_features(X_train:np.ndarray, X_test:np.ndarray, X_val:np.ndarray, use_standard_scaler:bool=False) -> tuple:
    if(use_standard_scaler):
        scaler = StandardScaler() # Create Z-Score normalizer
    else:
        scaler = MinMaxScaler() # Create Min-Max normalizer
    X_train_norm = np.zeros(shape=(X_train.shape), dtype='float32') # Create empty array for normalized train-data
    X_test_norm = np.zeros(shape=(X_test.shape), dtype='float32') # Create empty array for normalized test-data
    X_val_norm = np.zeros(shape=(X_val.shape), dtype='float32') # Create empty array for normalized val-data
    for feature_col in range(X_train.shape[2]): # Iterate over features in dataset
        X_train_norm[:,:,feature_col] = scaler.fit_transform(X_train[:,:,feature_col]) # Fit and apply normalizer on current feature in train subset
        X_test_norm[:,:,feature_col] = scaler.transform(X_test[:,:,feature_col]) # Apply normalizer on current feature in test subset
        X_val_norm[:,:,feature_col] = scaler.transform(X_val[:,:,feature_col]) # Apply normalizer on current feature in val subset
    return X_train_norm, X_test_norm, X_val_norm

# %%
X_train_normalized, X_test_normalized, X_val_normalized = normalize_features(X_train, X_test, X_val, True)

# %% [markdown]
# ## 5. Autoencoder
# The following section contains the data-preperation, build and training of the autoencoder. <br>
#
# <b>What is an autoencoder?</b><br>
# An autoencoder is a neural network architecture, that is used for unsupervised machine learning tasks. It consists out of two main components: The encoder & decoder. The encoder takes the input data and transforms it into a lower dimensional representation of the data, the so-called "latent-space". The decoder-part takes this data and tries to reconstruct the original input data. The main target during the training-phase is to minimize the reconstruction error. <br>
#
# <b>How can autoencoders be used for the detection of epileptic seizures in EEG-data?</b><br>
# There are two options how autoencoders can be used for the detection of epileptic seizures in EEG-data: Reconstruction-Error & Latent-Space. <br>
# By training the autoencoder only on data that does not contain any epileptic seizures, the reconstruction error for "normal" data is minimized. That means that if a sample with an active seizure is predicted, the reconstruction error will be increased. By defining an error-threshold, a binary classification can be performed to seperate normal samples from samples with an epileptic seizure.
#
# The second option is to use the latent space for the classification. The autoencoder is trained on the complete dataset with the same task of minimizing the reconstruction error. By seperating the decoding-component from the autoencoder, the latent space is exposed. Because of the differences in the data when an epileptic seizure is present, the representation of these samples must be different in the reduced space. Based on this assumption, a classification by using a clustering-approach can be done.
#
# The following code contains the second approach.
# ### 5.1 Define Autoencoder-Model
# **Adam** is used as the optimizer and the **binary crossentropy** used for the loss function.
#
# *Note: This project was build on M1 mac. To enshure best performance, the legacy version of the Adam optimizer was used. This can be changed when using windows or newer Versions of Tensorflow!*

# %%
X_train_anomalies = X_train_normalized[np.where(y_train == 1)[0]]

X_val_anomalies = X_val_normalized[np.where(y_val == 1)[0]]

X_test_anomalies = X_test_normalized[np.where(y_test == 1)[0]]

# %%
def build_and_compile_ae(train_shape:tuple, initla_lr:float=0.0001):
    inputs = Input(shape=(train_shape[1], train_shape[2]))
    # Encoder
    E1 = Conv1D(filters=24, kernel_size=3, activation='relu', padding='same')(inputs)
    E2 = MaxPooling1D(pool_size=2, padding='same')(E1)
    E3 = Conv1D(filters=12, kernel_size=3, activation='relu', padding='same')(E2)
    E4 = MaxPooling1D(pool_size=2, padding='same')(E3)
    latent_vector = Conv1D(filters=6, kernel_size=3, activation='relu', padding='same')(E4)
    # Decoder
    D1 = Conv1D(filters=6, kernel_size=3, activation='relu', padding='same')(latent_vector)
    D2 = UpSampling1D(size=2)(D1)
    D3 = Conv1D(filters=12, kernel_size=3, activation='relu', padding='same')(D2)
    D4 = UpSampling1D(size=2)(D3)
    D5 = Conv1D(filters=24, kernel_size=3, activation='relu', padding='same')(D4)
    ae_outputs = Dense(train_shape[2])(D5)

    autoencoder = Model(inputs=inputs, outputs=ae_outputs)
    opt = tf.keras.optimizers.legacy.Adam(learning_rate=0.001)

    autoencoder.compile(optimizer=opt, loss='mse')
    return autoencoder, inputs, latent_vector

# %% [markdown]
# ### 5.2 Compile Autoencoder-Model
# In order to train the neural network, the model defined in the previous step must be compiled. Furthermore, two **callbacks** are defined: **Early Stopping** and a **dynamic Learning Rate**. Both callbacks monitor the validation loss and stop the fitting process after a defined number of epochs without any improvement or reduce the learing rate to enable better results. Finally, the model is plottet to visualize the structure, number of parameters and enable the detection of errors in the definition.

# %%
autoencoder, ae_inputs, latent_vector = build_and_compile_ae(X_train.shape, 0.001)

earlystopper_ae = EarlyStopping(monitor='val_loss', patience=10, start_from_epoch=10, restore_best_weights=True, verbose=1)
reduce_lr_ae = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0000001, verbose=1, cooldown=10)

autoencoder.summary()
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1000, 24)]        0
#
#  conv1d (Conv1D)             (None, 1000, 24)          1752
#
#  max_pooling1d (MaxPooling1D  (None, 500, 24)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 500, 12)           876
#
#  max_pooling1d_1 (MaxPooling  (None, 250, 12)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 250, 6)            222
#
#  conv1d_3 (Conv1D)           (None, 250, 6)            114
#
#  up_sampling1d (UpSampling1D  (None, 500, 6)           0
#  )
#
#  conv1d_4 (Conv1D)           (None, 500, 12)           228
#
#  up_sampling1d_1 (UpSampling  (None, 1000, 12)         0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 1000, 24)          888
#
#  dense (Dense)               (None, 1000, 24)          600
#
# =================================================================
# Total params: 4,680
# Trainable params: 4,680
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 5.3 Fit Autoencoder-Model
# Fitting the neural network stands for the training process of the weights and bias of each layer to enable good predictions. The normalized training data is used for the training step and a validation is performed after every epoch via the normalized validation split to detect and prevent overfitting. Different to a "normal" training process using the features and labels, the feature-data is used for both input and output. After training, the progression of the training and validation loss is visualized for the easy visualization of the fit-process and further detection of overfitting or other issues during the training. In addition, an example of the original and reconstructed data is plottet to see the capabilities of the autoencoder. Finally, the model is saved as an .h5 file to be able to load the model an/or weights during later testing without new training.

# %%
history_ae = autoencoder.fit(
    X_train_anomalies, 
    X_train_anomalies,
    epochs=1000,
    batch_size=50,
    validation_data=(X_val_anomalies, X_val_anomalies),
    shuffle=True,
    verbose=1,
    callbacks=[earlystopper_ae, reduce_lr_ae]
)
# Out:
# 2023-07-02 12:00:31.298619: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/500
# 92/92 [==============================] - 42s 356ms/step - loss: 1.5754 - val_loss: 1.4416 - lr: 0.0010
# Epoch 2/500
# 92/92 [==============================] - 22s 243ms/step - loss: 1.2557 - val_loss: 1.2205 - lr: 0.0010
# Epoch 3/500
# 92/92 [==============================] - 21s 225ms/step - loss: 1.1140 - val_loss: 1.1344 - lr: 0.0010
# Epoch 4/500
# 92/92 [==============================] - 19s 202ms/step - loss: 1.0698 - val_loss: 1.1045 - lr: 0.0010
# Epoch 5/500
# 92/92 [==============================] - 17s 188ms/step - loss: 1.0390 - val_loss: 1.0676 - lr: 0.0010
# Epoch 6/500
# 92/92 [==============================] - 19s 202ms/step - loss: 1.0014 - val_loss: 1.0332 - lr: 0.0010
# Epoch 7/500
# 92/92 [==============================] - 17s 181ms/step - loss: 0.9715 - val_loss: 1.0032 - lr: 0.0010
# Epoch 8/500
# 92/92 [==============================] - 16s 170ms/step - loss: 0.9486 - val_loss: 0.9825 - lr: 0.0010
# Epoch 9/500
# 92/92 [==============================] - 16s 173ms/step - loss: 0.9300 - val_loss: 0.9639 - lr: 0.0010
# Epoch 10/500
# 92/92 [==============================] - 17s 180ms/step - loss: 0.9086 - val_loss: 0.9371 - lr: 0.0010
# Epoch 11/500
# 92/92 [==============================] - 17s 186ms/step - loss: 0.8851 - val_loss: 0.9171 - lr: 0.0010
# Epoch 12/500
# 92/92 [==============================] - 17s 185ms/step - loss: 0.8713 - val_loss: 0.9066 - lr: 0.0010
# Epoch 13/500
# 92/92 [==============================] - 17s 180ms/step - loss: 0.8630 - val_loss: 0.9035 - lr: 0.0010
# Epoch 14/500
# 92/92 [==============================] - 16s 171ms/step - loss: 0.8570 - val_loss: 0.8929 - lr: 0.0010
# Epoch 15/500
# 92/92 [==============================] - 16s 175ms/step - loss: 0.8515 - val_loss: 0.8893 - lr: 0.0010
# Epoch 16/500
# 92/92 [==============================] - 16s 173ms/step - loss: 0.8487 - val_loss: 0.8873 - lr: 0.0010
# Epoch 17/500
# 92/92 [==============================] - 15s 158ms/step - loss: 0.8455 - val_loss: 0.8838 - lr: 0.0010
# Epoch 18/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.8429 - val_loss: 0.8803 - lr: 0.0010
# Epoch 19/500
# 92/92 [==============================] - 15s 164ms/step - loss: 0.8405 - val_loss: 0.8787 - lr: 0.0010
# Epoch 20/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.8384 - val_loss: 0.8768 - lr: 0.0010
# Epoch 21/500
# 92/92 [==============================] - 15s 163ms/step - loss: 0.8380 - val_loss: 0.8931 - lr: 0.0010
# Epoch 22/500
# 92/92 [==============================] - 15s 165ms/step - loss: 0.8362 - val_loss: 0.8731 - lr: 0.0010
# Epoch 23/500
# 92/92 [==============================] - 15s 162ms/step - loss: 0.8339 - val_loss: 0.8721 - lr: 0.0010
# Epoch 24/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.8333 - val_loss: 0.8709 - lr: 0.0010
# Epoch 25/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.8320 - val_loss: 0.8710 - lr: 0.0010
# Epoch 26/500
# 92/92 [==============================] - 17s 187ms/step - loss: 0.8306 - val_loss: 0.8688 - lr: 0.0010
# Epoch 27/500
# 92/92 [==============================] - 16s 178ms/step - loss: 0.8294 - val_loss: 0.8681 - lr: 0.0010
# Epoch 28/500
# 92/92 [==============================] - 16s 169ms/step - loss: 0.8280 - val_loss: 0.8676 - lr: 0.0010
# Epoch 29/500
# 92/92 [==============================] - 15s 165ms/step - loss: 0.8281 - val_loss: 0.8662 - lr: 0.0010
# Epoch 30/500
# 92/92 [==============================] - 15s 165ms/step - loss: 0.8262 - val_loss: 0.8640 - lr: 0.0010
# Epoch 31/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.8259 - val_loss: 0.8639 - lr: 0.0010
# Epoch 32/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8242 - val_loss: 0.8631 - lr: 0.0010
# Epoch 33/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8239 - val_loss: 0.8614 - lr: 0.0010
# Epoch 34/500
# 92/92 [==============================] - 12s 132ms/step - loss: 0.8220 - val_loss: 0.8600 - lr: 0.0010
# Epoch 35/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8208 - val_loss: 0.8623 - lr: 0.0010
# Epoch 36/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8210 - val_loss: 0.8581 - lr: 0.0010
# Epoch 37/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8184 - val_loss: 0.8565 - lr: 0.0010
# Epoch 38/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8172 - val_loss: 0.8550 - lr: 0.0010
# Epoch 39/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8157 - val_loss: 0.8536 - lr: 0.0010
# Epoch 40/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8134 - val_loss: 0.8495 - lr: 0.0010
# Epoch 41/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8114 - val_loss: 0.8494 - lr: 0.0010
# Epoch 42/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8087 - val_loss: 0.8452 - lr: 0.0010
# Epoch 43/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8062 - val_loss: 0.8420 - lr: 0.0010
# Epoch 44/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.8028 - val_loss: 0.8385 - lr: 0.0010
# Epoch 45/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8034 - val_loss: 0.8351 - lr: 0.0010
# Epoch 46/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7984 - val_loss: 0.8333 - lr: 0.0010
# Epoch 47/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7961 - val_loss: 0.8324 - lr: 0.0010
# Epoch 48/500
# 92/92 [==============================] - 12s 132ms/step - loss: 0.7941 - val_loss: 0.8288 - lr: 0.0010
# Epoch 49/500
# 92/92 [==============================] - 12s 132ms/step - loss: 0.7926 - val_loss: 0.8271 - lr: 0.0010
# Epoch 50/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7908 - val_loss: 0.8246 - lr: 0.0010
# Epoch 51/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7891 - val_loss: 0.8241 - lr: 0.0010
# Epoch 52/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7886 - val_loss: 0.8213 - lr: 0.0010
# Epoch 53/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7859 - val_loss: 0.8202 - lr: 0.0010
# Epoch 54/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7850 - val_loss: 0.8198 - lr: 0.0010
# Epoch 55/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7834 - val_loss: 0.8173 - lr: 0.0010
# Epoch 56/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7824 - val_loss: 0.8159 - lr: 0.0010
# Epoch 57/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7814 - val_loss: 0.8159 - lr: 0.0010
# Epoch 58/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7804 - val_loss: 0.8141 - lr: 0.0010
# Epoch 59/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7799 - val_loss: 0.8132 - lr: 0.0010
# Epoch 60/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7782 - val_loss: 0.8117 - lr: 0.0010
# Epoch 61/500
# 92/92 [==============================] - 12s 131ms/step - loss: 0.7774 - val_loss: 0.8125 - lr: 0.0010
# Epoch 62/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7772 - val_loss: 0.8127 - lr: 0.0010
# Epoch 63/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7764 - val_loss: 0.8091 - lr: 0.0010
# Epoch 64/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7751 - val_loss: 0.8080 - lr: 0.0010
# Epoch 65/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7738 - val_loss: 0.8072 - lr: 0.0010
# Epoch 66/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7739 - val_loss: 0.8081 - lr: 0.0010
# Epoch 67/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7732 - val_loss: 0.8061 - lr: 0.0010
# Epoch 68/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7723 - val_loss: 0.8066 - lr: 0.0010
# Epoch 69/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7718 - val_loss: 0.8049 - lr: 0.0010
# Epoch 70/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7709 - val_loss: 0.8064 - lr: 0.0010
# Epoch 71/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7703 - val_loss: 0.8036 - lr: 0.0010
# Epoch 72/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7701 - val_loss: 0.8038 - lr: 0.0010
# Epoch 73/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7694 - val_loss: 0.8045 - lr: 0.0010
# Epoch 74/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7692 - val_loss: 0.8022 - lr: 0.0010
# Epoch 75/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7681 - val_loss: 0.8029 - lr: 0.0010
# Epoch 76/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7679 - val_loss: 0.8013 - lr: 0.0010
# Epoch 77/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7682 - val_loss: 0.8012 - lr: 0.0010
# Epoch 78/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7672 - val_loss: 0.8003 - lr: 0.0010
# Epoch 79/500
# 92/92 [==============================] - 13s 135ms/step - loss: 0.7680 - val_loss: 0.7998 - lr: 0.0010
# Epoch 80/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7662 - val_loss: 0.7997 - lr: 0.0010
# Epoch 81/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7655 - val_loss: 0.7984 - lr: 0.0010
# Epoch 82/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7654 - val_loss: 0.8004 - lr: 0.0010
# Epoch 83/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7652 - val_loss: 0.7982 - lr: 0.0010
# Epoch 84/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7651 - val_loss: 0.8000 - lr: 0.0010
# Epoch 85/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7646 - val_loss: 0.7975 - lr: 0.0010
# Epoch 86/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7643 - val_loss: 0.7969 - lr: 0.0010
# Epoch 87/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7637 - val_loss: 0.7978 - lr: 0.0010
# Epoch 88/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7632 - val_loss: 0.7961 - lr: 0.0010
# Epoch 89/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7635 - val_loss: 0.7952 - lr: 0.0010
# Epoch 90/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7628 - val_loss: 0.7949 - lr: 0.0010
# Epoch 91/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7624 - val_loss: 0.7971 - lr: 0.0010
# Epoch 92/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7626 - val_loss: 0.7950 - lr: 0.0010
# Epoch 93/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7616 - val_loss: 0.7943 - lr: 0.0010
# Epoch 94/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7620 - val_loss: 0.7946 - lr: 0.0010
# Epoch 95/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7613 - val_loss: 0.7951 - lr: 0.0010
# Epoch 96/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7619 - val_loss: 0.7952 - lr: 0.0010
# Epoch 97/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7606 - val_loss: 0.7931 - lr: 0.0010
# Epoch 98/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7605 - val_loss: 0.7926 - lr: 0.0010
# Epoch 99/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7598 - val_loss: 0.7922 - lr: 0.0010
# Epoch 100/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7603 - val_loss: 0.7933 - lr: 0.0010
# Epoch 101/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7613 - val_loss: 0.7927 - lr: 0.0010
# Epoch 102/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7593 - val_loss: 0.7921 - lr: 0.0010
# Epoch 103/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7591 - val_loss: 0.7922 - lr: 0.0010
# Epoch 104/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7594 - val_loss: 0.7928 - lr: 0.0010
# Epoch 105/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7589 - val_loss: 0.7915 - lr: 0.0010
# Epoch 106/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7588 - val_loss: 0.7909 - lr: 0.0010
# Epoch 107/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7590 - val_loss: 0.7979 - lr: 0.0010
# Epoch 108/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7586 - val_loss: 0.7903 - lr: 0.0010
# Epoch 109/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7581 - val_loss: 0.7907 - lr: 0.0010
# Epoch 110/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7577 - val_loss: 0.7907 - lr: 0.0010
# Epoch 111/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7578 - val_loss: 0.7920 - lr: 0.0010
# Epoch 112/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7575 - val_loss: 0.7911 - lr: 0.0010
# Epoch 113/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7573
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7573 - val_loss: 0.7905 - lr: 0.0010
# Epoch 114/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7559 - val_loss: 0.7885 - lr: 5.0000e-04
# Epoch 115/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7557 - val_loss: 0.7884 - lr: 5.0000e-04
# Epoch 116/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7556 - val_loss: 0.7885 - lr: 5.0000e-04
# Epoch 117/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7557 - val_loss: 0.7882 - lr: 5.0000e-04
# Epoch 118/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7554 - val_loss: 0.7884 - lr: 5.0000e-04
# Epoch 119/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7554 - val_loss: 0.7884 - lr: 5.0000e-04
# Epoch 120/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7553 - val_loss: 0.7880 - lr: 5.0000e-04
# Epoch 121/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7552 - val_loss: 0.7879 - lr: 5.0000e-04
# Epoch 122/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7551 - val_loss: 0.7882 - lr: 5.0000e-04
# Epoch 123/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7550 - val_loss: 0.7878 - lr: 5.0000e-04
# Epoch 124/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7549 - val_loss: 0.7874 - lr: 5.0000e-04
# Epoch 125/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7548 - val_loss: 0.7877 - lr: 5.0000e-04
# Epoch 126/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7547 - val_loss: 0.7874 - lr: 5.0000e-04
# Epoch 127/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7546 - val_loss: 0.7875 - lr: 5.0000e-04
# Epoch 128/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7545 - val_loss: 0.7873 - lr: 5.0000e-04
# Epoch 129/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7544 - val_loss: 0.7874 - lr: 5.0000e-04
# Epoch 130/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7544 - val_loss: 0.7869 - lr: 5.0000e-04
# Epoch 131/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7542 - val_loss: 0.7871 - lr: 5.0000e-04
# Epoch 132/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7542 - val_loss: 0.7868 - lr: 5.0000e-04
# Epoch 133/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7540 - val_loss: 0.7875 - lr: 5.0000e-04
# Epoch 134/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7540 - val_loss: 0.7864 - lr: 5.0000e-04
# Epoch 135/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7539 - val_loss: 0.7864 - lr: 5.0000e-04
# Epoch 136/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7537 - val_loss: 0.7859 - lr: 5.0000e-04
# Epoch 137/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7536 - val_loss: 0.7860 - lr: 5.0000e-04
# Epoch 138/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7535 - val_loss: 0.7862 - lr: 5.0000e-04
# Epoch 139/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7534 - val_loss: 0.7858 - lr: 5.0000e-04
# Epoch 140/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7536 - val_loss: 0.7868 - lr: 5.0000e-04
# Epoch 141/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7532 - val_loss: 0.7857 - lr: 5.0000e-04
# Epoch 142/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7529 - val_loss: 0.7853 - lr: 5.0000e-04
# Epoch 143/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7529 - val_loss: 0.7852 - lr: 5.0000e-04
# Epoch 144/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7530 - val_loss: 0.7859 - lr: 5.0000e-04
# Epoch 145/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7527 - val_loss: 0.7854 - lr: 5.0000e-04
# Epoch 146/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7528 - val_loss: 0.7853 - lr: 5.0000e-04
# Epoch 147/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7526
# Epoch 147: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7526 - val_loss: 0.7857 - lr: 5.0000e-04
# Epoch 148/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7520 - val_loss: 0.7844 - lr: 2.5000e-04
# Epoch 149/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7518 - val_loss: 0.7844 - lr: 2.5000e-04
# Epoch 150/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7518 - val_loss: 0.7843 - lr: 2.5000e-04
# Epoch 151/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7517 - val_loss: 0.7843 - lr: 2.5000e-04
# Epoch 152/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7516 - val_loss: 0.7843 - lr: 2.5000e-04
# Epoch 153/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7517 - val_loss: 0.7841 - lr: 2.5000e-04
# Epoch 154/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7515 - val_loss: 0.7841 - lr: 2.5000e-04
# Epoch 155/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7515 - val_loss: 0.7841 - lr: 2.5000e-04
# Epoch 156/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7515 - val_loss: 0.7841 - lr: 2.5000e-04
# Epoch 157/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7515 - val_loss: 0.7839 - lr: 2.5000e-04
# Epoch 158/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7514 - val_loss: 0.7841 - lr: 2.5000e-04
# Epoch 159/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7513 - val_loss: 0.7837 - lr: 2.5000e-04
# Epoch 160/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7513 - val_loss: 0.7837 - lr: 2.5000e-04
# Epoch 161/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7512 - val_loss: 0.7836 - lr: 2.5000e-04
# Epoch 162/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7511 - val_loss: 0.7836 - lr: 2.5000e-04
# Epoch 163/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7511 - val_loss: 0.7835 - lr: 2.5000e-04
# Epoch 164/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7510 - val_loss: 0.7837 - lr: 2.5000e-04
# Epoch 165/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7510 - val_loss: 0.7834 - lr: 2.5000e-04
# Epoch 166/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7510 - val_loss: 0.7834 - lr: 2.5000e-04
# Epoch 167/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7509 - val_loss: 0.7835 - lr: 2.5000e-04
# Epoch 168/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7508
# Epoch 168: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7508 - val_loss: 0.7834 - lr: 2.5000e-04
# Epoch 169/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7505 - val_loss: 0.7829 - lr: 1.2500e-04
# Epoch 170/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7504 - val_loss: 0.7829 - lr: 1.2500e-04
# Epoch 171/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7504 - val_loss: 0.7831 - lr: 1.2500e-04
# Epoch 172/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7504 - val_loss: 0.7829 - lr: 1.2500e-04
# Epoch 173/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7504 - val_loss: 0.7829 - lr: 1.2500e-04
# Epoch 174/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7503 - val_loss: 0.7830 - lr: 1.2500e-04
# Epoch 175/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7503 - val_loss: 0.7828 - lr: 1.2500e-04
# Epoch 176/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7503 - val_loss: 0.7828 - lr: 1.2500e-04
# Epoch 177/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7502 - val_loss: 0.7828 - lr: 1.2500e-04
# Epoch 178/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7502 - val_loss: 0.7828 - lr: 1.2500e-04
# Epoch 179/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7501 - val_loss: 0.7827 - lr: 1.2500e-04
# Epoch 180/500
# 92/92 [==============================] - 12s 134ms/step - loss: 0.7501 - val_loss: 0.7826 - lr: 1.2500e-04
# Epoch 181/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7501 - val_loss: 0.7827 - lr: 1.2500e-04
# Epoch 182/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7501 - val_loss: 0.7825 - lr: 1.2500e-04
# Epoch 183/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7500 - val_loss: 0.7825 - lr: 1.2500e-04
# Epoch 184/500
# 92/92 [==============================] - 12s 133ms/step - loss: 0.7500 - val_loss: 0.7826 - lr: 1.2500e-04
# Epoch 185/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7499 - val_loss: 0.7824 - lr: 1.2500e-04
# Epoch 186/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7499 - val_loss: 0.7824 - lr: 1.2500e-04
# Epoch 187/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7498 - val_loss: 0.7824 - lr: 1.2500e-04
# Epoch 188/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7499 - val_loss: 0.7824 - lr: 1.2500e-04
# Epoch 189/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7498 - val_loss: 0.7823 - lr: 1.2500e-04
# Epoch 190/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7497 - val_loss: 0.7823 - lr: 1.2500e-04
# Epoch 191/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7497 - val_loss: 0.7822 - lr: 1.2500e-04
# Epoch 192/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7496 - val_loss: 0.7821 - lr: 1.2500e-04
# Epoch 193/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7496 - val_loss: 0.7821 - lr: 1.2500e-04
# Epoch 194/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7496 - val_loss: 0.7821 - lr: 1.2500e-04
# Epoch 195/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7496 - val_loss: 0.7820 - lr: 1.2500e-04
# Epoch 196/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7495 - val_loss: 0.7820 - lr: 1.2500e-04
# Epoch 197/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7495 - val_loss: 0.7819 - lr: 1.2500e-04
# Epoch 198/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7495 - val_loss: 0.7820 - lr: 1.2500e-04
# Epoch 199/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7494 - val_loss: 0.7818 - lr: 1.2500e-04
# Epoch 200/500
# 92/92 [==============================] - 12s 136ms/step - loss: 0.7494 - val_loss: 0.7818 - lr: 1.2500e-04
# Epoch 201/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7493 - val_loss: 0.7818 - lr: 1.2500e-04
# Epoch 202/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7493 - val_loss: 0.7818 - lr: 1.2500e-04
# Epoch 203/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7492 - val_loss: 0.7817 - lr: 1.2500e-04
# Epoch 204/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7492 - val_loss: 0.7816 - lr: 1.2500e-04
# Epoch 205/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7491 - val_loss: 0.7817 - lr: 1.2500e-04
# Epoch 206/500
# 92/92 [==============================] - 13s 137ms/step - loss: 0.7492 - val_loss: 0.7817 - lr: 1.2500e-04
# Epoch 207/500
# 92/92 [==============================] - 13s 138ms/step - loss: 0.7492 - val_loss: 0.7816 - lr: 1.2500e-04
# Epoch 208/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7491 - val_loss: 0.7815 - lr: 1.2500e-04
# Epoch 209/500
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7490 - val_loss: 0.7813 - lr: 1.2500e-04
# Epoch 210/500
# 92/92 [==============================] - 12s 135ms/step - loss: 0.7490 - val_loss: 0.7816 - lr: 1.2500e-04
# Epoch 211/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7490 - val_loss: 0.7814 - lr: 1.2500e-04
# Epoch 212/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7489 - val_loss: 0.7817 - lr: 1.2500e-04
# Epoch 213/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7489 - val_loss: 0.7815 - lr: 1.2500e-04
# Epoch 214/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7489
# Epoch 214: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7489 - val_loss: 0.7812 - lr: 1.2500e-04
# Epoch 215/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7487 - val_loss: 0.7811 - lr: 6.2500e-05
# Epoch 216/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7486 - val_loss: 0.7811 - lr: 6.2500e-05
# Epoch 217/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7486 - val_loss: 0.7812 - lr: 6.2500e-05
# Epoch 218/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7486 - val_loss: 0.7811 - lr: 6.2500e-05
# Epoch 219/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7486 - val_loss: 0.7811 - lr: 6.2500e-05
# Epoch 220/500
# 92/92 [==============================] - 14s 153ms/step - loss: 0.7486 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 221/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7486 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 222/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7486 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 223/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7485 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 224/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7485 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 225/500
# 92/92 [==============================] - 14s 153ms/step - loss: 0.7485 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 226/500
# 92/92 [==============================] - 15s 161ms/step - loss: 0.7485 - val_loss: 0.7809 - lr: 6.2500e-05
# Epoch 227/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7484 - val_loss: 0.7810 - lr: 6.2500e-05
# Epoch 228/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7485 - val_loss: 0.7808 - lr: 6.2500e-05
# Epoch 229/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7484 - val_loss: 0.7809 - lr: 6.2500e-05
# Epoch 230/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7484 - val_loss: 0.7808 - lr: 6.2500e-05
# Epoch 231/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7484 - val_loss: 0.7808 - lr: 6.2500e-05
# Epoch 232/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7483 - val_loss: 0.7809 - lr: 6.2500e-05
# Epoch 233/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7483 - val_loss: 0.7807 - lr: 6.2500e-05
# Epoch 234/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7483 - val_loss: 0.7808 - lr: 6.2500e-05
# Epoch 235/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7483 - val_loss: 0.7807 - lr: 6.2500e-05
# Epoch 236/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7483 - val_loss: 0.7807 - lr: 6.2500e-05
# Epoch 237/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7482 - val_loss: 0.7807 - lr: 6.2500e-05
# Epoch 238/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7482
# Epoch 238: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7482 - val_loss: 0.7806 - lr: 6.2500e-05
# Epoch 239/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7481 - val_loss: 0.7806 - lr: 3.1250e-05
# Epoch 240/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7481 - val_loss: 0.7806 - lr: 3.1250e-05
# Epoch 241/500
# 92/92 [==============================] - 14s 156ms/step - loss: 0.7481 - val_loss: 0.7806 - lr: 3.1250e-05
# Epoch 242/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7481 - val_loss: 0.7806 - lr: 3.1250e-05
# Epoch 243/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7481 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 244/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7481 - val_loss: 0.7806 - lr: 3.1250e-05
# Epoch 245/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7481 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 246/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7480 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 247/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7480 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 248/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7480 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 249/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7480 - val_loss: 0.7805 - lr: 3.1250e-05
# Epoch 250/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7480 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 251/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7480 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 252/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7480 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 253/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7480 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 254/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7480 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 255/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7479
# Epoch 255: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7479 - val_loss: 0.7804 - lr: 3.1250e-05
# Epoch 256/500
# 92/92 [==============================] - 15s 159ms/step - loss: 0.7479 - val_loss: 0.7804 - lr: 1.5625e-05
# Epoch 257/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7479 - val_loss: 0.7804 - lr: 1.5625e-05
# Epoch 258/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 259/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 260/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 261/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 262/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 263/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 264/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7479 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 265/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7478 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 266/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7478 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 267/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7478 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 268/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.7478 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 269/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7478
# Epoch 269: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7478 - val_loss: 0.7803 - lr: 1.5625e-05
# Epoch 270/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 271/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 272/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 273/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 274/500
# 92/92 [==============================] - 14s 156ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 275/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 276/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 277/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 278/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 279/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 280/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7478 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 281/500
# 92/92 [==============================] - 15s 159ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 282/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 283/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 283: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 7.8125e-06
# Epoch 284/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 285/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 286/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 287/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 288/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 289/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 290/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 291/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 292/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 293/500
# 92/92 [==============================] - 15s 158ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 294/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 295/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 296/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 297/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 297: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 3.9063e-06
# Epoch 298/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 1.9531e-06
# Epoch 299/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 1.9531e-06
# Epoch 300/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 1.9531e-06
# Epoch 301/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7802 - lr: 1.9531e-06
# Epoch 302/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 303/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 304/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 305/500
# 92/92 [==============================] - 15s 160ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 306/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 307/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 308/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 309/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 310/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 311/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 311: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.9531e-06
# Epoch 312/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 313/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 314/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 315/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 316/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 317/500
# 92/92 [==============================] - 15s 161ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 318/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 319/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 320/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 321/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 322/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 323/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 324/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 325/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 325: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 9.7656e-07
# Epoch 326/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 327/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 328/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 329/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 330/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 331/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 332/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 333/500
# 92/92 [==============================] - 15s 164ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 334/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 335/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 336/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 337/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 338/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 339/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 339: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 4.8828e-07
# Epoch 340/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 341/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 342/500
# 92/92 [==============================] - 14s 153ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 343/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 344/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 345/500
# 92/92 [==============================] - 15s 163ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 346/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 347/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 348/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 349/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 350/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 351/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 352/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 353/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 353: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 92/92 [==============================] - 14s 153ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 2.4414e-07
# Epoch 354/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 355/500
# 92/92 [==============================] - 15s 160ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 356/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 357/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 358/500
# 92/92 [==============================] - 15s 162ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 359/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 360/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 361/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 362/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 363/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 364/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 365/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 366/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 367/500
# 92/92 [==============================] - ETA: 0s - loss: 0.7477
# Epoch 367: ReduceLROnPlateau reducing learning rate to 1e-07.
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.2207e-07
# Epoch 368/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 369/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 370/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 371/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 372/500
# 92/92 [==============================] - 14s 156ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 373/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 374/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 375/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 376/500
# 92/92 [==============================] - 14s 152ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 377/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 378/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 379/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 380/500
# 92/92 [==============================] - 15s 160ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 381/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 382/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 383/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 384/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 385/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 386/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 387/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 388/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 389/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 390/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 391/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 392/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 393/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 394/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 395/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 396/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 397/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 398/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 399/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 400/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 401/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 402/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 403/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 404/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 405/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 406/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 407/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 408/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 409/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 410/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 411/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 412/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 413/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 414/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 415/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 416/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 417/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 418/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 419/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 420/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 421/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 422/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 423/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 424/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 425/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 426/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 427/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 428/500
# 92/92 [==============================] - 13s 139ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 429/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 430/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 431/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 432/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 433/500
# 92/92 [==============================] - 13s 141ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 434/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 435/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 436/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 437/500
# 92/92 [==============================] - 13s 145ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 438/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 439/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 440/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 441/500
# 92/92 [==============================] - 13s 140ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 442/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 443/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 444/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7477 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 445/500
# 92/92 [==============================] - 14s 156ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 446/500
# 92/92 [==============================] - 15s 168ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 447/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 448/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 449/500
# 92/92 [==============================] - 14s 157ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 450/500
# 92/92 [==============================] - 14s 151ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 451/500
# 92/92 [==============================] - 11s 120ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 452/500
# 92/92 [==============================] - 11s 119ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 453/500
# 92/92 [==============================] - 11s 117ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 454/500
# 92/92 [==============================] - 11s 118ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 455/500
# 92/92 [==============================] - 11s 117ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 456/500
# 92/92 [==============================] - 10s 113ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 457/500
# 92/92 [==============================] - 10s 111ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 458/500
# 92/92 [==============================] - 10s 110ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 459/500
# 92/92 [==============================] - 10s 112ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 460/500
# 92/92 [==============================] - 10s 111ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 461/500
# 92/92 [==============================] - 10s 111ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 462/500
# 92/92 [==============================] - 10s 106ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 463/500
# 92/92 [==============================] - 10s 106ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 464/500
# 92/92 [==============================] - 10s 106ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 465/500
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 466/500
# 92/92 [==============================] - 10s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 467/500
# 92/92 [==============================] - 10s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 468/500
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 469/500
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 470/500
# 92/92 [==============================] - 9s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 471/500
# 92/92 [==============================] - 9s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 472/500
# 92/92 [==============================] - 9s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 473/500
# 92/92 [==============================] - 9s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 474/500
# 92/92 [==============================] - 10s 104ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 475/500
# 92/92 [==============================] - 10s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 476/500
# 92/92 [==============================] - 9s 102ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 477/500
# 92/92 [==============================] - 9s 103ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 478/500
# 92/92 [==============================] - 12s 130ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 479/500
# 92/92 [==============================] - 14s 153ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 480/500
# 92/92 [==============================] - 13s 144ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 481/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 482/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 483/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 484/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 485/500
# 92/92 [==============================] - 14s 149ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 486/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 487/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 488/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 489/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 490/500
# 92/92 [==============================] - 14s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 491/500
# 92/92 [==============================] - 13s 147ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 492/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 493/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 494/500
# 92/92 [==============================] - 14s 150ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 495/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 496/500
# 92/92 [==============================] - 13s 143ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 497/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 498/500
# 92/92 [==============================] - 13s 142ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 499/500
# 92/92 [==============================] - 14s 148ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07
# Epoch 500/500
# 92/92 [==============================] - 13s 146ms/step - loss: 0.7476 - val_loss: 0.7801 - lr: 1.0000e-07

# %%
fig = go.Figure(
    data = [
        go.Scatter(y=history_ae.history['loss'], name="train"),
        go.Scatter(y=history_ae.history['val_loss'], name="val"),
    ],
    layout = {"yaxis": {"title": "Loss [MSE]"}, "xaxis": {"title": "Epoch"}, "title": "Reconstruction Loss over Epochs"}
)

fig.show()

# %% [markdown]
# ### 5.4 Visualize Reconstruction

# %%
a = np.transpose(X_train_anomalies, (0,2,1))
data = []
for i in range(len(a[0])):
    data.append(
        go.Scatter(y=a[0,i], name=channels[i])
    )

fig = go.Figure(
    data = data,
    layout = {"yaxis": {"title": "Original Channel Value"}, "xaxis": {"title": "Timestep"}, "title": "Reconstructed EEG-Sample"}
)

fig.show()

# %%
pred = autoencoder.predict(X_train_anomalies[:1])
a = np.transpose(pred, (0,2,1))
data = []
for i in range(len(a[0])):
    data.append(
        go.Scatter(y=a[0,i], name=channels[i])
    )

fig = go.Figure(
    data = data,
    layout = {"yaxis": {"title": "Normalized Channel Value"}, "xaxis": {"title": "Timestep"}, "title": "Reconstructed EEG-Sample"}
)

fig.show()
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
# autoencoder.save('../99_Assets/01_Saved Models/04_autoencoder_latent_space_clustering.h5')
autoencoder = tf.keras.models.load_model('../99_Assets/01_Saved Models/04_autoencoder_latent_space_clustering.h5')

# %% [markdown]
# ## 6. Seperate Encoder & Create Dataset
# After training the autoencoder, it is split at the latent space and a new model is formed containing only the encoder. With this, a dataset of the latent space is created for the test samples, which can be used for clustering in the next step.

# %%
encoder = Model(inputs=ae_inputs, outputs=latent_vector)

# %%
cluster_space = encoder.predict(X_test_anomalies)
# Out:
# 48/48 [==============================] - 0s 4ms/step

# %% [markdown]
# ## 7. Clustering of latent space
# After the creation, training and splitting of the autoencoder, a clustering of the latent space can be performed.
#
# ### 7.1 Define Cluster
# Due to the presence of time series formats in the latent space, a TimeSeriesKMeans is applied for clustering. Since the main goal of clustering is to distinguish between local and generalized seizures, two clusters are formed.

# %%
ts_kmeans = TimeSeriesKMeans(n_clusters=2, metric="euclidean", max_iter=50, random_state=0)
ts_kmeans.fit(cluster_space)
# Out:
# TimeSeriesKMeans(n_clusters=2, random_state=0)

# %% [markdown]
# ### 7.2 Clustering
# Using the latent space of the test split as well as the defined TimeSeriesKMeans, the clustering is now performed and the results are stored.

# %%
pred = ts_kmeans.predict(cluster_space)

# %%
cluster_1 = X_test_anomalies[np.where(pred == 0)[0]]
cluster_2 = X_test_anomalies[np.where(pred == 1)[0]]

# %% [markdown]
# ### 7.3 Visualize Clusters
# Due to the high dimensionality as well as the time series format, no simple visualization of the created clusters is possible. Therefore, by comparing samples of the two clusters, we try to draw a conclusion about the distinction made.

# %%
a = np.transpose(cluster_1, (0,2,1))
data = []
for i in range(len(a[0])):
    data.append(
        go.Scatter(y=a[0,i], name=channels[i])
    )

fig = go.Figure(
    data = data,
    layout = {"yaxis": {"title": "Normalized Channel Value"}, "xaxis": {"title": "Timestep"}, "title": "EEG-Sample - Cluster 1"}
)

fig.show()

# %%
a = np.transpose(cluster_2, (0,2,1))
data = []
for i in range(len(a[0])):
    data.append(
        go.Scatter(y=a[0,i], name=channels[i])
    )

fig = go.Figure(
    data = data,
    layout = {"yaxis": {"title": "Normalized Channel Value"}, "xaxis": {"title": "Epoch"}, "title": "EEG-Sample - Cluster 2"}
)

fig.show()

# %% [markdown]
# ## 8. Conclusion
